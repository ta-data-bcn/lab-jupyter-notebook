# %% [markdown]
# # First Jupyter Notebook Lab <a class="anchor" id="chapter0"></a>

# %% [markdown]
# ## Table of contents
#
# * [1. Description of destination](#chapter1)
# * [2. Video](#chapter2)
# * [3. Image](#chapter3)
# * [4. Input area](#chapter4)
# * [5. Top 3 things to do](#chapter5)

# %% [markdown]
# ### 1. Description of destination <a class="anchor" id="chapter1"></a>

# %% [markdown]
# Hello, my name is Nick. My favourite holiday destination would be Maui, Hawaii.

# %% [markdown]
# ### 2. Video <a class="anchor" id="chapter2"></a>

# %% [markdown]
# To give you an image of how Maui is, I want to show you a youtube video __[here.](https://www.youtube.com/watch?v=n58bdYZP-lI)__

# %% [markdown]
# ### 3. Image <a class="anchor" id="chapter3"></a>

# %% [markdown]
# To give you something extra, I also added a picture below:

# %% [markdown]
# ![picturemaui.jpg](attachment:picturemaui.jpg)

# %% [markdown]
# ### 4. Input area <a class="anchor" id="chapter4"></a>

# %%
name = input("Your name: ")
print("Nice to meet you,",name)
# Out:
# Your name: Nick
# Nice to meet you, Nick

# %% [markdown]
# ![hawaiishirt.jpg](attachment:hawaiishirt.jpg)

# %%
fav_dest = input("Tell me your favourite holiday destination: ")
print("Nice, I like",fav_dest, "as well!")
# Out:
# Tell me your favourite holiday destination: Spain
# Nice, I like Spain as well!

# %% [markdown]
# ![peopleonbeach.jpg](attachment:peopleonbeach.jpg)

# %% [markdown]
# ### 5. Top 3 things to do <a class="anchor" id="chapter5"></a>

# %% [markdown]
# - **Surfing**
# - *Tanning on the beach*
# - <span style="color:green">Drink</span> <span style="color:orange">cocktails</span> <span style="color:red">in</span> <span style="color:blue">the</span> <span style="color:pink">sun</span>

# %% [markdown]
# __[Last video of Maui, Hawaii](http://www.youtube.com/watch?v=JFh38v0HJyQ)__

# %% [markdown]
# * [Back to top](#chapter0)
