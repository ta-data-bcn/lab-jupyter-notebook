# %% [markdown]
# # [Iceland](#iceland)

# %% [markdown]
# #### My name is Ramón and one of the best holidays that i've had was in <font color =green>Iceland </font>

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo(id="F-1weFCiYBA", width=600,height=400)

# %% [markdown]
# <a id="iceland"></a>

# %% [markdown]
# ##### Top three things of my trip to Iceland:
# - [Changing landscape](#change)
# - [Camping with a Defender](#camp)
# - [Northern lights](#lights)

# %% [markdown]
# <a id="#change"></a>
# There is a mix of landscapes. Within ours you pass from glaciers to rocky and mossy roads

# %% [markdown]
# ![Screenshot_20200623-170957__01.jpg](attachment:Screenshot_20200623-170957__01.jpg)

# %% [markdown]
# <a id="camp"></a>
# If you plan on going there, you defenitly need to camp. It changes the hole trip for the better!

# %% [markdown]
# ![Screenshot_20200623-102041__01__01.jpg](attachment:Screenshot_20200623-102041__01__01.jpg)

# %% [markdown]
# <a id="lights"></a>
# And if you are lucky, you get to see one oh these...bucket list experience

# %% [markdown]
# ![Screenshot_20200623-101940__01__01.jpg](attachment:Screenshot_20200623-101940__01__01.jpg)
